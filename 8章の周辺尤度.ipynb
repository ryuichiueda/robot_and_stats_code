# %%
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt

# %%
data = np.random.normal(loc=0,scale = 1,size=1000)
data = np.sort(data)
data_mean = np.mean(data)
data_stdev = np.std(data)

print(data_mean)
print(data_stdev)
# Out:
# 0.04001713340860124
# 0.9773946608798172

# %%
likelihood_sum = sum([norm.pdf(e,data_mean, data_stdev) for e in data])
print(likelihood_sum)
# Out:
# 287.6855047997971

# %%
data2 = [data[0:500], data[501:]]
data_means = [ np.mean(e) for e in data2]
data_stdevs = [ np.std(e) for e in data2 ]

print(data_means)
print(data_stdevs)
# Out:
# [-0.7396610757925978, 0.8212882131950169]
# [0.5747892457901729, 0.603227515210159]

# %%
likelihood_sums = 0
for i in range(2):
    likelihood_sums += sum( [norm.pdf(e,data_means[i], data_stdevs[i]) for e in data2[i] ] )/2
print(likelihood_sums)
# Out:
# 237.95736647515795

# %%
x = np.arange(-3,3,0.01)

plt.plot(x,norm.pdf(x,data_mean,data_stdev) ,color='r')
plt.plot(x,norm.pdf(x,data_means[0],data_stdevs[0])/2 ,color='b')
plt.plot(x,norm.pdf(x,data_means[1],data_stdevs[1])/2 ,color='b')
